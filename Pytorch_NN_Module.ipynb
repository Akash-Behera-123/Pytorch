# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-Behera-123/Pytorch/blob/main/Pytorch_NN_Module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create model class
import torch
import torch.nn as nn

class Model(nn.Module):
    def __init__(self,num_features):
       super().__init__()
       self.linear =nn.Linear(num_features,1)
       self.sigmoid = nn.Sigmoid()
    def forward(self,x):
        out = self.linear(x)
        out = self.sigmoid(out) # Also fixed sigmoid input to 'out'
        return out

# %%
#create dataset
features = torch.rand(10,5)

#create model
model=Model(features.shape[1])

#call model for forwardpass
#model.forward(features)
model(features)
# Out:
# tensor([[0.5891],
#         [0.5249],
#         [0.5301],
#         [0.5465],
#         [0.5459],
#         [0.5268],
#         [0.5356],
#         [0.5035],
#         [0.5607],
#         [0.5046]], grad_fn=<SigmoidBackward0>)

# %%
#show model weights
model.linear.bias
# Out:
# Parameter containing:
# tensor([-0.1579], requires_grad=True)

# %%
# !pip install torchinfo

# %%
from torchinfo import summary
summary(model,input_size=(10,5))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Model                                    [10, 1]                   --
# ├─Linear: 1-1                            [10, 1]                   6
# ├─Sigmoid: 1-2                           [10, 1]                   --
# ...
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ...
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ...

# %% [markdown]
# Neural Network with hidden layers

# %%
#create model class
import torch
import torch.nn as nn

class Model2(nn.Module):
    def __init__(self,num_features):
       super().__init__()
       self.linear =nn.Linear(num_features,3)
       self.relu = nn.ReLU()
       self.linear2 =nn.Linear(3,1)
       self.sigmoid = nn.Sigmoid
    def forward(self,features):
        out = self.linear1(features)
        out = self.relu(out)
        out = self.linear2(out)
        out = self.sigmoid(out) # Also fixed sigmoid input to 'out'
        return out

# %%
#create model class (redefined for fix in this cell)
import torch
import torch.nn as nn

class Model2(nn.Module):
    def __init__(self,num_features):
       super().__init__()
       self.linear =nn.Linear(num_features,3) # Fixed: This is 'linear', not 'linear1'
       self.relu = nn.ReLU()
       self.linear2 =nn.Linear(3,1)
       self.sigmoid = nn.Sigmoid() # Fixed: Added () to instantiate Sigmoid
    def forward(self,features):
        out = self.linear(features) # Fixed: Changed from self.linear1 to self.linear
        out = self.relu(out)
        out = self.linear2(out)
        out = self.sigmoid(out)
        return out

#create dataset
features = torch.rand(10,5)

#create model
model2=Model2(features.shape[1])

#call model for forwardpass
#model.forward(features)
model2(features)

# %%
from torchinfo import summary
summary(model2,input_size=(10,5))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Model2                                   [10, 1]                   --
# ├─Linear: 1-1                            [10, 3]                   18
# ├─ReLU: 1-2                              [10, 3]                   --
# ├─Linear: 1-3                            [10, 1]                   4
# ├─Sigmoid: 1-4                           [10, 1]                   --
# ...
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ...
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ...
